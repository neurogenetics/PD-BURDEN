# %% [markdown]
# # Generating setList for Pathway Analysis
# - Using the MSigDB C8 cell-type gene sets
# - Downloaded Oct 5 2021 (v7.4)
# - For PD Burdens project

# %%
import pandas as pd
import csv 
import numpy as np

# %%
## Make list of all possible genes in incoming file
! awk '{$1=$2=""; print $0}' c8.all.v7.4.symbols.gmt > list_of_genes_c8.txt # Copy everything other than the first 2 columns 
! tr ' ' '\n' < list_of_genes_c8.txt > pre_file_list_of_genes_c8.txt # Convert the spaces between each gene to new lines 
! sed '/^$/d' pre_file_list_of_genes_c8.txt > file_list_of_genes_c8.txt # Remove any empty rows from the file to prevent problems later 

# Clean up
! rm list_of_genes_c8.txt
! rm pre_file_list_of_genes_c8.txt

## Read in file
with open('file_list_of_genes_c8.txt') as f:
    all_genes = f.read().splitlines()

# %%
## Read in the coordinates file
coordinates_file = pd.read_csv("hg38_refFlat_annotables_BioMart_genes_coordinates_OCT2021.txt", sep="\t")
coordinates_dict = dict(zip(coordinates_file.gene_name, coordinates_file.Coordinates))

# %%
## Compare with dictionary and see what genes are missing
missing_genes = [] # Initialize empty list 
for gene in all_genes:
    if gene not in coordinates_dict:
        missing_genes.append(gene)

unique_missing_genes = list(set(missing_genes)) # Make unique list of genes missing 
print(unique_missing_genes)
len(unique_missing_genes)
# Out:
# []
# 0

# %%
## Make a function that maps the dictionary values 
def replace(list, dictionary):
    return [dictionary.get(item, item) for item in list]

# Make an array of the weird chromsome prefixes to remove (if there are any)
prefixes = ('CHR_')

# Initialize an empty list 
list_of_pathways = []
list_of_error_pathways = [] 

# Read in the MSigDB .gmt file 
# Loop through the c2 file 
with open('c8.all.v7.4.symbols.gmt', 'r') as f:
    reader = csv.reader(f, dialect='excel', delimiter='\t')
    for row in reader:
        del row[1] # Remove the 2nd element, the ones with the website link 
        number_of_genes = len(row)
        row2 = replace(row, coordinates_dict) # Map the coordinates to the gene symbols
        row3 = [element for element in row2 if not element.startswith(prefixes)] # Remove any of those weird prefixes 
        number_of_found_genes = len(row2)
        if number_of_genes != number_of_found_genes:
            list_of_error_pathways.append(row3)
        #print(row3)
        list_of_pathways.append(row3) # Add to the list of lists

# %%
## Sanity check, see if any of the now converted pathways have more or less genes than the input file 
len(list_of_error_pathways)
# Out:
# 0

# %%
# Save out the file 
with open('c8.all.v7.4.symbols.setFile.Oct52021.txt', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(list_of_pathways)

# %%
# No idea how to do this in Python but use bash to replace the FIRST comma with a tab and remove the temp file
! sed 's/,/'$'\t''/' c8.all.v7.4.symbols.setFile.Oct52021.txt > c8.all.v7.4.symbols.setFile.Oct52021.final.txt
! rm c8.all.v7.4.symbols.setFile.Oct52021.txt
! wc -l c8.all.v7.4.symbols.setFile.Oct52021.final.txt
# Out:
#      671 c8.all.v7.4.symbols.setFile.Oct52021.final.txt

# %%
! grep -w "GBA" c8.all.v7.4.symbols.gmt # GBA not in the C8 files

# %%
! grep -w "LRRK2" c8.all.v7.4.symbols.gmt | head -3 # LRRK2 is in C8 files lets check if its in the setFile
# Out:
# FAN_EMBRYONIC_CTX_OPC	http://www.gsea-msigdb.org/gsea/msigdb/cards/FAN_EMBRYONIC_CTX_OPC	PDGFRA	EPN2	SCRG1	PLPPR1	APOD	ARL4A	COL9A1	PCDH15	BEX1	MEG3	GRIA2	THY1	PLAT	LINC00643	PLLP	BCHE	LHFPL3	LRRC4C	GPR17	LIMA1	COL20A1	CA10	CNTN1	PHLDA1	SLC35F1	SEMA5A	SNAP25	KLRC2	PCSK1N	IL1RAP	SCN1A	SPRY4	SCG3	MPZL1	PDE4B	BRINP1	VXN	TAOK3	OLIG1	NXPH1	ARL2BP	TSPAN13	UCHL1	SLC1A1	ATCAY	C2orf80	CXADR	LRRK2	SNTG1	CCND1	TM4SF1	FIP1L1	PCDH20	BRINP3	CNPY2
# MANNO_MIDBRAIN_NEUROTYPES_HMGL	http://www.gsea-msigdb.org/gsea/msigdb/cards/MANNO_MIDBRAIN_NEUROTYPES_HMGL	A2M	ABCG1	ABI3	ACSF2	ACSL5	ACY3	ADAM28	ADAMTSL4-AS1	ADAP2	ADAT2	ADCK2	ADCY7	ADORA3	ADPGK	AFF1	AGR2	ALOX5	ALOX5AP	ANKRD44	ANXA11	ANXA4	ANXA5	AP1B1	APBB1IP	APOBEC3C	APOBEC3D	APOBR	APOC1	APOC2	APOE	ARHGAP25	ARHGAP26	ARHGAP4	ARHGDIB	ARHGEF6	ARPC1B	ARRB2	ARRDC2	ASAH1	ATF3	PGGHG	ATP8B4	AXL	B2M	B3GNT5	B4GALT1	BAG3	BCAP29	BCL2A1	BCL3	BDNF	BHLHE41	BIN1	BIN2	BIRC3	BLNK	BLVRB	BMP2K	BRI3	BTK	C12orf75	C17orf67	PITHD1	C1orf54	C1QA	C1QB	C1QC	C3	C3AR1	CAPG	CAPZB	CARD11	CARD9	CASP1	CASP4	CASP9	CCDC17	CCDC175	CCL2	CCL3	CCL4	CCR1	CCRL2	CD14	CD163	CD274	CD36	CD37	CD4	CD44	CD48	CD53	CD5L	CD68	CD69	CD74	CD83	CD84	CD86	CDH17	CDKN1A	CEBPA	CEBPD	CHCHD1	CLEC7A	CMKLR1	CNPY3	COLGALT1	CORO1B	CPED1	CPVL	CREG1	CREM	CRYBB1	CSF1	CSF1R	CSF3R	CSRNP1	CTDSP1	CTSB	CTSC	CTSD	CTSH	CTSL	CTSS	CX3CR1	CXCL2	CXCL8	TASL	CYBA	CYBB	CYFIP1	CYTH4	CYTIP	DAB2	INTS6L	DENND3	DENND4A	DEPTOR	DERL3	DHRS3	DHRS9	DNAJA4	DNAJB1	DNAJB4	DOCK1	DOCK4	DOCK8	DOK2	DPF3	DPP7	DRAM1	DRAM2	DUSP1	DUSP2	EDEM1	EFHD2	EGR1	EGR2	EGR3	ELF1	ELL2	ELOVL1	ENTPD1	ERF	ERMAP	ETS2	EVI2A	EVI2B	EXOSC5	FABP3	NIBAN1	TENT5A	FAR2	FCER1G	FCGR1A	FCGR1B	FCGR2A	FCGR3A	FCGRT	FERMT3	FGD2	FGL1	FGL2	FHL3	FKBP15	FKBP4	FKBP5	FLI1	FOLR2	FOSB	FOXN3	FOXO3	FPR1	FTL	FYB1	GAB3	GADD45B	GAL3ST4	GAS6	GATM	GIMAP4	GIMAP5	GLIPR1	GLRX	GM2A	GMFG	GNB4	GNG7	GNGT2	GPNMB	GPR137B	GPR183	GPR34	GPR65	GPRIN3	GPX1	TAMALIN	GRN	GSN	GYPC	HAUS4	HAVCR2	HBA1	HBA2	HBG1	HBG2	HCLS1	HCST	HERPUD1	HHEX	ARHGAP45	HMOX1	HPGDS	HPSE	HRH1	HS3ST1	HSD17B14	HSPA6	HSPA7	HSPB1	HSPD1	HSPH1	HTRA1	ICA1	ICAM1	IER2	IER5	IFI16	IFNGR1	IGF1	IGFBP3	IGSF6	IKBKE	IKZF1	IL13RA1	IL16	IL17RA	IL18	IL1B	IL1R1	IL27RA	IL4R	IL6R	IL6ST	IL7R	INPP5D	INPPL1	IPCEF1	IRAK2	IRF1	IRF8	ITGAV	ITGB2	ITM2B	ITPR2	ITPRIPL2	ITSN2	JAK3	JUNB	ANOS1	KBTBD8	KCNE3	KCNK13	KCNK3	KCNK6	KCTD12	KIAA1755	KIF14	KLF2	KLF3	KRT14	KRT17	KRT5	LAIR1	LAPTM5	LAT2	LCP1	P3H2	LGMN	LHFPL2	LILRA2	LILRB4	LIMS1	LIPA	LITAF	LPAR5	LPAR6	LPCAT2	LPL	LRRC8C	LRRK2	LTBR	LY86	LY96	LYN	LYST	MAF	MAFB	MAFF	MALT1	MANBA	MAP2K3	MAP3K5	MAP3K8	MARCHF1	MBP	MCTP1	MEF2C	MERTK	METTL7A	MFNG	MFSD1	MFSD12	MGST2	MICOS10-NBL1	MIR221	MKNK1	MLKL	MMRN1	MNDA	MOB3C	MPEG1	MPP1	MRC1	MS4A4A	MS4A7	MYADM	MYLIP	MYO1F	NAGA	NAIP	NAV3	NCF2	NCF4	NCKAP1L	NEAT1	NEK6	NEU4	NFATC1	NFATC2	NFKBIA	NFKBIZ	NINJ1	NKX2-2	NLRP3	NPC1	NPC2	NPL	NR3C1	NR4A1	NR4A2	NRG2	NUP37	OAS1	OGFRL1	OLFML3	OLR1	OPRK1	OSTF1	OTUD1	P2RX4	P2RY12	P2RY13	PAG1	PALD1	PAQR8	PARP14	PARP9	PARVG	PCDH12	PCDHGC3	PCED1B-AS1	PDK4	PDPN	PIEZO1	PIK3CG	PIK3IP1	PLA2G15	PLAU	PLAUR	PLCB2	PLCG2	PLD4	PLEK	PLSCR1	PLVAP	PLXDC2	PMAIP1	PNRC1	POLD4	POU2F2	PPFIA4	PPIF	PPP1R15A	PPP3R1	PPT1	PRDM1	PRKCA	PROCR	PTAFR	PTGER4	PTGS2	PTK2B	PTPN18	PTPN6	PTPRC	PTPRE	PYCARD	PYGL	RAB13	RAB32	RAB3IL1	RAP2C	RASAL3	RASGEF1B	RASSF3	RASSF4	RBM47	RCSD1	REL	RGL1	RGS1	RGS19	RHBDF2	RHOG	RILPL2	RIN2	RIPK3	RNASE6	RNASET2	RNF125	RNF213	RPS6KA4	RREB1	RUNX1	RUNX3	RYR2	SAMHD1	SAMSN1	SASH3	SAT1	SCAMP2	SCARB1	SCARNA9	SCIN	SCPEP1	SELPLG	SEPTIN6	SERPINF1	SFMBT2	SGK1	SH2B3	SIGLEC1	SIGLEC14	SIRPA	SKAP2	SLA	SLC11A2	SLC15A3	SLC1A5	SLC25A19	SLC25A39	SLC37A2	SLC4A1	SLC4A4	SLC6A3	SLC7A11	SLC7A7	SLC9A9	SLCO2B1	SNHG12	SNORD114-1	SNX1	SNX18	SOD2	SORL1	SOX14	SPI1	SPINT2	SPP1	SQSTM1	SRGN	ST6GAL1	STAB1	STAT1	STAT5A	STAT6	CDK7	STK17B	STOM	STX11	STXBP2	SUCLG2	SYK	SYNGR2	SYT6	TAGAP	TAL1	TBC1D12	TESC	TFEC	TGFBR2	TIAM1	TICAM1	TLN1	TLR1	TLR4	TLR7	TM6SF1	TMBIM1	TMC8	TMEM119	TMEM144	ANO1	STING1	TMEM19	TMEM63A	TNFAIP3	TNFRSF11B	TNFRSF1A	TNFRSF1B	LTA	TNFSF9	TOR3A	TOR4A	TPP1	TPT1	TREM2	TRIM22	TRIM38	TRPV2	TXNIP	TYMP	TYROBP	UBA7	UBC	UCP2	ULBP1	USP36	VAMP8	VAV1	VSIG4	WASF2	WIPF1	WNT7B	XAF1	YPEL2	ZC3H12A	ZC3HAV1	ZFAND2A	ZFP36	ZFP36L1	ZFP36L2	TMEM35B	ZNF217	ZNF48
# MANNO_MIDBRAIN_NEUROTYPES_HOPC	http://www.gsea-msigdb.org/gsea/msigdb/cards/MANNO_MIDBRAIN_NEUROTYPES_HOPC	ACSS1	ADAM22	ADAMTS3	ADAMTS6	ADCYAP1R1	AFAP1L2	AFF1	AGA	AIF1L	AK4	AKAP7	ANGPTL2	ANKRD44	ANKS1B	APOD	APOL6	ARC	ARHGAP11A	CHN1	ARHGAP23	ARHGAP42	ARL8A	ASCL1	ASTN1	ATCAY	ATP13A2	ATP13A4	ATP1B1	ATP1B2	ATP2B4	B4GALNT1	B4GALT6	BAALC	ADGRB1	BAMBI	BARD1	BCAN	BCHE	BIRC3	BIRC5	BIVM-ERCC5	BLOC1S1	BOC	BRINP1	BRINP2	BRINP3	BUB1B	C1orf21	MIR9-1HG	C1QL1	C21orf58	C2orf27A	C2orf72	THUMPD2	VXN	CA1	CACFD1	CACNA1G	CACNG2	CACNG7	CADM2	CADM4	CALCRL	CASK	CCDC175	CCDC39	CCND2	CDCA7L	CEND1	CEP83-DT	CGREF1	CHKB-CPT1B	CHST11	CHTF8	CMYA5	CNTN1	COL2A1	COL9A1	COL9A3	CPEB1	CPNE2	CREB5	CRTAC1	CRYL1	CSGALNACT1	CSMD3	CSPG5	CTHRC1	CTNND2	BCLAF3	DBI	DCLK2	DHX32	DNAAF3	DNAH7	DND1	DNER	DNM3	DOCK1	DPP6	DSEL	EDNRB	EFCAB14	EGFR	EGR1	EID2B	ELF1	ELFN2	EPN2	ERBB3	ERF	ETV1	ETV5	EVI2A	EYA2	FABP5	FABP7	FALEC	FAM155A	FAM181B	FAM182B	TAFA2	TAFA5	FAM89A	FGFBP3	FICD	FXYD6	FYN	GAB1	GABBR2	GAL3ST1	GAREM2	GATM	GFOD1	GNAL	GNG4	GNG7	GPM6A	GPM6B	GPR17	ADGRG1	GRAMD1C	TAMALIN	GRB14	GRIA3	GRIA4	GRID1	GRID2	GRM5	GTSE1	HAGH	HBA1	HBA2	HBB	HBG1	HBG2	HEPACAM	HEPN1	HES5	HSH2D	IDH1	IFI27L2	IGF1	IGFBP2	INHBB	INTS1	ITGAV	ITGB5	ITGB8	ITM2C	ITPKB	ITPR2	JPH3	KANK1	KCND2	KCNE5	KCNIP1	KCNJ1	KCNQ2	KIF13A	KIF14	KLRC2	KRT14	KRT17	CNMD	LGR5	LHFPL2	LHFPL3	LIMA1	LINGO1	LMOD3	LPAR4	PLPPR1	PLPPR2	LRP1	LRRC4C	LRRK2	LRRTM3	LRRTM4	LUZP2	MAML2	MAP3K1	MCTP1	MDGA2	METRN	METTL7A	IGSF9B	MMP16	MMP2	MT2A	MT3	MYT1	NCAM2	NCAPH	NDRG2	NEIL1	NEK6	NELL1	NETO1	NFIX	NKAIN4	NKX2-2	NLGN1	NLGN2	NLGN3	NLGN4Y	NPAS3	NRXN1	NTM	NTRK3	NXPH1	OLIG1	OLIG2	OMG	OPCML	OPHN1	OSBPL6	PBK	PCDH11X	PCDH15	PCDH17	PCDHGC3	PCDHA7	PCDHGB4	PDE1C	PDGFRA	PEA15	PHACTR3	PHGDH	PHLDA1	PHYHIPL	PID1	PIF1	PLAT	PLEKHH2	PLLP	PMP2	PMP22	PLPP4	PPP2R2B	PRDM8	PREX1	PRKCA	PRKCQ-AS1	PSD	PTN	PTPRE	PTPRT	PTPRZ1	PXDC1	QKI	RAB31	RAB9A	RARG	RFTN2	RIMS1	RIT2	RNF144A	ROBO3	RTKN2	RUNDC3A	SALL3	SAPCD2	SCAMP2	SCARB1	SCD5	SCG3	SCN1A	SCN3A	SCRG1	SCUBE2	SDC3	SEL1L3	SERINC5	SERPINE2	SEZ6	SEZ6L	SGO1	SGO2	SH3D19	SHC3	SIRT2	SKA3	SLC15A2	SLC16A14	SLC1A2	SLC22A17	SLC25A16	SLC35F1	SLC44A1	SLC6A1	SLC7A11	SLC9A3R1	SLC9A7	SLC9A9	SLITRK1	SLITRK2	SLITRK4	SMOC1	SNTG1	SORCS3	SOX1	SOX2	SOX2-OT	SOX5	SOX6	SOX8	SOX9	SOX9-AS1	SPATA6	SPRED1	SPRY4	SRI	SSPOP	CDK7	STK32B	TAF1B	TAOK3	TF	THY1	TIMP4	TMOD1	TMOD2	TNK2	TNS1	TOP3A	TPPP	TRAF4	TRIM67	TRIM68	TSPAN12	TSPAN7	TTK	TTYH1	TYMS	UBL3	UHRF1	WFDC1	WNT7B	WSCD1	XYLT1	ZCCHC24	ZFP36L1	ZGRF1	ZMAT3	TMEM35B

# %%
! grep -w "12:40196743-40369285" c8.all.v7.4.symbols.setFile.Oct52021.final.txt | head -2 # Right where you expect them
# Out:
# FAN_EMBRYONIC_CTX_OPC	4:54229279-54298245,17:19215614-19336715,4:173384700-173406380,9:101028726-101325135,3:195568704-195584033,7:12686855-12690958,6:70215060-70303083,10:53802770-55627942,X:103062650-103064171,14:100779409-100861031,4:157204181-157366075,11:119415475-119424985,8:42174717-42207676,14:62114352-62130962,16:57248546-57284672,3:165772903-165837462,7:104328699-104907232,11:40114202-41459773,2:127645863-127652639,12:50175787-50283546,20:63293185-63334851,17:51630312-52160017,12:40692438-41072415,12:76025446-76033932,6:117907263-118317676,5:9035032-9546075,20:10218829-10307418,12:10426853-10442300,X:48831095-48835610,3:190514050-190659750,2:165984640-166149214,5:142310426-142326455,15:51681491-51721026,1:167721191-167791919,1:65792513-66374579,9:119153457-119369435,8:66493519-66518524,12:118149800-118372907,21:33070140-33072413,7:8433608-8752961,16:57245258-57253635,7:16753754-16784536,4:41256412-41268455,9:4490467-4587469,19:3879863-3928082,2:208165342-208190030,21:17513042-17593579,12:40196743-40369285,8:49909788-50796692,11:69641155-69654474,3:149369021-149377692,4:53377640-53460862,13:61409684-61415522,1:190097657-190478404,12:56309841-56316119
# MANNO_MIDBRAIN_NEUROTYPES_HMGL	12:9067663-9116229,21:42199688-42297244,17:49210410-49223225,17:50426157-50474845,10:112374017-112428380,11:67642554-67650730,8:24294068-24359014,1:150560201-150574552,17:30906343-30959322,6:143422831-143450695,7:140672944-140696261,16:50246136-50318135,1:111499428-111503633,15:72751368-72785846,4:86935001-87141054,7:16791810-16833433,10:45374175-45446119,13:30713477-30764426,2:196967016-197311173,10:80150888-80205572,2:69644424-69827112,4:121667945-121696995,22:29327679-29423179,10:26438340-26567803,22:39014256-39020352,22:39021112-39033277,16:28494642-28498970,19:44914246-44919349,19:44946034-44949565,19:44905790-44909393,2:68679600-68826833,5:142770376-143229011,X:153907366-153934999,12:14942030-14961728,X:136665546-136780932,7:99374248-99394816,17:4710595-4721499,19:18001131-18014102,8:18055991-18084998,1:212565333-212620777,11:289125-296107,15:49858237-50182817,19:41219222-41261766,15:44711486-44718877,3:183253252-183298504,9:33104081-33167356,10:119651379-119677819,7:107579976-107629170,15:79960891-79971196,19:44747704-44760044,11:27654892-27722058,12:26120029-26125037,2:127048026-127107288,12:51281037-51324668,11:102317449-102339403,10:96189170-96271587,19:40447764-40465764,4:78776341-78916372,7:98252378-98310441,X:101349446-101390796,12:105235289-105396097,17:56791912-56838773,1:23778417-23788232,1:150268199-150280916,1:22636627-22639678,1:22652761-22661637,1:22643632-22648110,19:6677703-6730562,12:8056843-8066359,2:85394752-85418432,1:19338774-19485539,7:2906140-3043945,9:136361902-136373681,11:105025442-105035250,11:104942865-104969366,1:15490831-15526534,1:45620043-45624057,14:59504538-59576812,17:34255217-34257203,17:36088255-36090169,17:36103826-36105621,3:46201710-46208313,3:46407165-46412997,5:140631727-140633701,12:7470812-7503893,9:5450502-5470566,7:80369574-80679277,19:49335170-49343335,12:6786857-6820799,11:35138869-35232402,1:160678745-160711831,1:110871187-110899922,1:157830910-157898256,17:7579490-7582111,12:9752485-9760901,5:150400040-150412929,6:14117255-14136918,1:160541094-160579516,3:122055361-122121139,8:94127161-94217303,6:36676459-36687337,19:33299933-33302534,8:47736912-47738164,10:73782046-73783652,12:10116776-10130258,12:108288043-108339317,6:42929191-42939294,19:17555648-17583162,11:67435509-67443821,7:120988696-121297442,7:28995234-29195451,1:167529116-167553805,10:35126790-35212958,22:26599277-26618027,1:109910241-109930992,5:150053290-150113372,1:36466042-36483278,3:39141854-39154562,2:218398255-218405941,8:11842523-11869448,11:88293591-88337761,11:1752754-1764573,15:78921057-78949574,9:87726108-87731469,1:150730187-150765792,3:39263494-39281735,4:74097039-74099196,4:73740540-73743716,X:30558809-30577766,16:88643288-88651054,X:37780058-37813461,15:22867051-22981063,22:37282026-37315341,2:157414618-157488961,5:39371674-39462300,X:135520642-135582510,8:141117277-141195808,15:65658045-65792293,8:119873716-120050918,22:23834502-23839128,1:12567909-12618210,2:169064788-169096167,15:78264085-78282196,19:14514768-14529770,1:77979174-78017964,10:126905408-127452517,7:111726109-112206407,9:214853-465259,8:21908872-21913690,14:72619295-72894116,9:137110545-137115177,12:101877579-102012130,1:111117332-111140216,5:172768095-172771195,2:96143168-96145440,3:5187645-5219958,1:15409887-15430339,5:138465478-138469303,10:62811995-62919900,8:22687658-22693480,13:40931923-41061440,5:95885097-95961851,1:43363397-43368074,10:95711778-95877266,19:42247568-42255128,1:42817121-42844991,21:38805182-38824955,17:31317559-31321884,17:31303769-31314105,19:41386373-41397359,1:31365252-31376850,1:184790723-184974508,6:81491438-81752774,12:29149102-29340980,1:161215233-161220699,1:149782670-149792518,1:121087344-121097161,1:161505429-161524013,1:161541758-161550737,19:49506815-49526428,11:64206677-64223886,6:37005645-37029069,8:17864379-17910365,7:77193368-77199848,1:37996769-38005606,9:113161005-113221318,12:2794969-2805423,6:35573584-35728583,11:128686534-128813267,11:72216600-72221950,19:4 ...

# %%
! grep "_alt" c8.all.v7.4.symbols.setFile.Oct52021.final.txt

# %%
! grep "CHR_" c8.all.v7.4.symbols.setFile.Oct52021.final.txt
